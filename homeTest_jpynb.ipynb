# %% [markdown]
# <a href="https://colab.research.google.com/github/mccoy0928/20230205_python_byVictorGau/blob/main/homeTest_jpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

# %%
#高雄市111年A1交通事故統計表
url = "https://api.kcg.gov.tw/api/service/get/ad197194-6db9-4f14-ad38-2adceea831c3"

# %%
url1="https://www.wantgoo.com/stock/etf/0050/constituent"

# %%
r = requests.get(url1).json()

# %%
import numpy as np
from matplotlib.pyplot import plot as plt
import pandas as pd

# %%
df = pd.read_html("https://www.moneydj.com/ETF/X/Basic/Basic0007a.xdjhtm?etfid=0050.TW") #元大台灣卓越50基金

# %%
print(df[2], df[3])

# %%
df3_list =[]
for i in range(25, 50):
  df3_list.append(i)

# %%
df[3].index = df3_list

# %%
dfupdate = df[2].append(df[3])

# %%
dfupdate
# Out:
#       股票名稱    持股(千股)     比例      增減
# 0      台積電  245502.0  47.90  +2.69%
# 1       鴻海  122097.0   4.55  -0.45%
# 2      聯發科   15203.0   4.08  +0.18%
# 3      台達電   22125.0   2.39  -0.21%
# 4       聯電  119516.0   2.18  +0.18%
# 5      富邦金   75551.0   1.70  -0.04%
# 6      中華電   39001.0   1.64  -0.16%
# 7       南亞   57837.0   1.63  -0.05%
# 8      中信金  184995.0   1.58  -0.10%
# 9       中鋼  125951.0   1.49  -0.05%
# 10     國泰金   91171.0   1.45  -0.05%
# 11     兆豐金  113883.0   1.36  -0.06%
# 12   日月光投控   34780.0   1.30  -0.04%
# 13     玉山金  138684.0   1.27  -0.10%
# 14      台塑   38049.0   1.27  -0.09%
# 15      統一   48897.0   1.23  -0.11%
# 16   中租-KY   14150.0   1.19  -0.07%
# 17     第一金  106606.0   1.04  -0.12%
# 18     元大金  122474.0   1.03  -0.06%
# 19     合庫金  103173.0   1.02  -0.08%
# 20      台化   34832.0   0.94  -0.07%
# 21      台泥   64948.0   0.88  -0.01%
# 22     華南金  103488.0   0.88  -0.08%
# 23     大立光    1045.0   0.83  -0.05%
# 24      國巨    4013.0   0.81  +0.07%
# ...

# %%
df['台灣-加權'].plot()
